# %%
import pandas as pd

# %%
df=pd.read_csv("E:\\DATA ANALYTICS ENGINEERING MASTERY COURSE\\PANDAS MATERIAL\\policedata.csv")

# %%
df.head(2)
# Out:
#    stop_date stop_time  country_name driver_gender  driver_age_raw  \
# 0   1/2/2005      1:55           NaN             M          1985.0
# 1  1/18/2005      8:15           NaN             M          1965.0
#
#    driver_age driver_race violation_raw violation  search_conducted  \
# 0        20.0       White      Speeding  Speeding             False
# 1        40.0       White      Speeding  Speeding             False
#
#   search_type stop_outcome is_arrested stop_duration  drugs_related_stop
# 0         NaN     Citation       False      0-15 Min               False
# 1         NaN     Citation       False      0-15 Min               False

# %%
df.shape
# Out:
# (65535, 15)

# %%
df.size
# Out:
# 983025

# %%
df.index
# Out:
# RangeIndex(start=0, stop=65535, step=1)

# %%
df.columns
# Out:
# Index(['stop_date', 'stop_time', 'country_name', 'driver_gender',
#        'driver_age_raw', 'driver_age', 'driver_race', 'violation_raw',
#        'violation', 'search_conducted', 'search_type', 'stop_outcome',
#        'is_arrested', 'stop_duration', 'drugs_related_stop'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# stop_date                 0
# stop_time                 0
# country_name          65535
# driver_gender          4061
# driver_age_raw         4054
# driver_age             4307
# driver_race            4060
# violation_raw          4060
# violation              4060
# search_conducted          0
# search_type           63056
# stop_outcome           4060
# is_arrested            4060
# stop_duration          4060
# drugs_related_stop        0
# dtype: int64

# %%
df.isnull().sum()*100/len(df)
# Out:
# stop_date               0.000000
# stop_time               0.000000
# country_name          100.000000
# driver_gender           6.196689
# driver_age_raw          6.186007
# driver_age              6.572061
# driver_race             6.195163
# violation_raw           6.195163
# violation               6.195163
# search_conducted        0.000000
# search_type            96.217288
# stop_outcome            6.195163
# is_arrested             6.195163
# stop_duration           6.195163
# drugs_related_stop      0.000000
# dtype: float64

# %% [markdown]
# ### Since here country_name & search_type containing null greater than 20 to 30 % so we have to delete it these two columns..

# %%
df.drop(columns=['country_name','search_type'],inplace=True)

# %%
df.isnull().sum()*100/len(df)
# Out:
# stop_date             0.000000
# stop_time             0.000000
# driver_gender         6.196689
# driver_age_raw        6.186007
# driver_age            6.572061
# driver_race           6.195163
# violation_raw         6.195163
# violation             6.195163
# search_conducted      0.000000
# stop_outcome          6.195163
# is_arrested           6.195163
# stop_duration         6.195163
# drugs_related_stop    0.000000
# dtype: float64

# %% [markdown]
# ### Now we can impute missing values of remaining col by measure of central tendency but first we need to explore datatype of each columns then we can decide so..

# %%
df.dtypes
# Out:
# stop_date              object
# stop_time              object
# driver_gender          object
# driver_age_raw        float64
# driver_age            float64
# driver_race            object
# violation_raw          object
# violation              object
# search_conducted         bool
# stop_outcome           object
# is_arrested            object
# stop_duration          object
# drugs_related_stop       bool
# dtype: object

# %%
df.isnull().sum()*100/len(df)
# Out:
# stop_date             0.000000
# stop_time             0.000000
# driver_gender         6.196689
# driver_age_raw        6.186007
# driver_age            6.572061
# driver_race           6.195163
# violation_raw         6.195163
# violation             6.195163
# search_conducted      0.000000
# stop_outcome          6.195163
# is_arrested           6.195163
# stop_duration         6.195163
# drugs_related_stop    0.000000
# dtype: float64

# %% [markdown]
# # First convert datatype of stop_date col from object to datetime

# %%
df['stop_date']=pd.to_datetime(df['stop_date'])

# %%
df.dtypes
# Out:
# stop_date             datetime64[ns]
# stop_time                     object
# driver_gender                 object
# driver_age_raw               float64
# driver_age                   float64
# driver_race                   object
# violation_raw                 object
# violation                     object
# search_conducted                bool
# stop_outcome                  object
# is_arrested                   object
# stop_duration                 object
# drugs_related_stop              bool
# dtype: object

# %% [markdown]
# #  We Can impute the missing values of 'Gender' col by mode of this col becoz it is Categorical datatype

# %%
df['driver_gender']=df.fillna(df['driver_gender'].mode())

# %%
df.isnull().sum()*100/len(df)
# Out:
# stop_date             0.000000
# stop_time             0.000000
# driver_gender         0.000000
# driver_age_raw        6.186007
# driver_age            6.572061
# driver_race           6.195163
# violation_raw         6.195163
# violation             6.195163
# search_conducted      0.000000
# stop_outcome          6.195163
# is_arrested           6.195163
# stop_duration         6.195163
# drugs_related_stop    0.000000
# dtype: float64

# %%
df.dtypes
# Out:
# stop_date             datetime64[ns]
# stop_time                     object
# driver_gender                 object
# driver_age_raw               float64
# driver_age                   float64
# driver_race                   object
# violation_raw                 object
# violation                     object
# search_conducted                bool
# stop_outcome                  object
# is_arrested                   object
# stop_duration                 object
# drugs_related_stop              bool
# dtype: object

# %%
df['driver_gender'].value_counts()
# Out:
# 2012-01-11    69
# 2012-02-28    65
# 2007-05-16    62
# 2012-01-02    61
# 2007-01-10    60
#               ..
# 2005-08-28     1
# 2005-04-01     1
# 2005-12-25     1
# 2005-09-03     1
# 2005-08-07     1
# Name: driver_gender, Length: 2651, dtype: int64

# %% [markdown]
# # Now as remainig null are ver less so  we can drop also..

# %%
df.dropna(inplace=True)

# %% [markdown]
# # Now as We can see our dataset is fully cleaned..

# %%
df.isnull().sum()*100/len(df)
# Out:
# stop_date             0.0
# stop_time             0.0
# driver_gender         0.0
# driver_age_raw        0.0
# driver_age            0.0
# driver_race           0.0
# violation_raw         0.0
# violation             0.0
# search_conducted      0.0
# stop_outcome          0.0
# is_arrested           0.0
# stop_duration         0.0
# drugs_related_stop    0.0
# dtype: float64

# %% [markdown]
# # Check Duplicated Records in dataset ?

# %%
df[df.duplicated()]
# Out:
#        stop_date stop_time        driver_gender  driver_age_raw  driver_age  \
# 16    2005-07-19      0:30  2005-07-19 00:00:00          1982.0        23.0
# 104   2005-10-03     13:26  2005-10-03 00:00:00          1975.0        30.0
# 117   2005-10-04      0:36  2005-10-04 00:00:00          1961.0        44.0
# 149   2005-10-05     10:00  2005-10-05 00:00:00          1981.0        24.0
# 239   2005-10-08     12:30  2005-10-08 00:00:00          1978.0        27.0
# ...          ...       ...                  ...             ...         ...
# 62244 2012-07-26      9:45  2012-07-26 00:00:00          1953.0        59.0
# 62474 2012-08-04     16:38  2012-08-04 00:00:00          1976.0        36.0
# 63849 2012-09-21     10:14  2012-09-21 00:00:00          1979.0        33.0
# 64323 2012-10-11      6:10  2012-10-11 00:00:00          1952.0        60.0
# 65407 2012-11-30     22:16  2012-11-30 00:00:00          1990.0        22.0
#
# ...

# %% [markdown]
# # So there are totally 192 records are duplicated so we can remove them ..

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# # So Now if we check then we will get no duplicates records ?

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [stop_date, stop_time, driver_gender, driver_age_raw, driver_age, driver_race, violation_raw, violation, search_conducted, stop_outcome, is_arrested, stop_duration, drugs_related_stop]
# Index: []

# %%
df
# Out:
#        stop_date stop_time        driver_gender  driver_age_raw  driver_age  \
# 0     2005-01-02      1:55  2005-01-02 00:00:00          1985.0        20.0
# 1     2005-01-18      8:15  2005-01-18 00:00:00          1965.0        40.0
# 2     2005-01-23     23:15  2005-01-23 00:00:00          1972.0        33.0
# 3     2005-02-20     17:15  2005-02-20 00:00:00          1986.0        19.0
# 4     2005-03-14     10:00  2005-03-14 00:00:00          1984.0        21.0
# ...          ...       ...                  ...             ...         ...
# 65529 2012-12-06     16:00  2012-12-06 00:00:00          1994.0        18.0
# 65530 2012-12-06     17:54  2012-12-06 00:00:00          1987.0        25.0
# 65531 2012-12-06     22:22  2012-12-06 00:00:00          1954.0        58.0
# 65532 2012-12-06     23:20  2012-12-06 00:00:00          1985.0        27.0
# 65534 2012-12-07      0:30  2012-12-07 00:00:00          1985.0        27.0
#
# ...

# %% [markdown]
# # Now after deleting two col and deleting duplicated rows we left with only 61031 rows and 13 col with full cleaned dataset

# %%
df
# Out:
#        stop_date stop_time        driver_gender  driver_age_raw  driver_age  \
# 0     2005-01-02      1:55  2005-01-02 00:00:00          1985.0        20.0
# 1     2005-01-18      8:15  2005-01-18 00:00:00          1965.0        40.0
# 2     2005-01-23     23:15  2005-01-23 00:00:00          1972.0        33.0
# 3     2005-02-20     17:15  2005-02-20 00:00:00          1986.0        19.0
# 4     2005-03-14     10:00  2005-03-14 00:00:00          1984.0        21.0
# ...          ...       ...                  ...             ...         ...
# 65529 2012-12-06     16:00  2012-12-06 00:00:00          1994.0        18.0
# 65530 2012-12-06     17:54  2012-12-06 00:00:00          1987.0        25.0
# 65531 2012-12-06     22:22  2012-12-06 00:00:00          1954.0        58.0
# 65532 2012-12-06     23:20  2012-12-06 00:00:00          1985.0        27.0
# 65534 2012-12-07      0:30  2012-12-07 00:00:00          1985.0        27.0
#
# ...

# %%
df.drop(columns='driver_gender')
# Out:
#        stop_date stop_time  driver_age_raw  driver_age driver_race  \
# 0     2005-01-02      1:55          1985.0        20.0       White
# 1     2005-01-18      8:15          1965.0        40.0       White
# 2     2005-01-23     23:15          1972.0        33.0       White
# 3     2005-02-20     17:15          1986.0        19.0       White
# 4     2005-03-14     10:00          1984.0        21.0       White
# ...          ...       ...             ...         ...         ...
# 65529 2012-12-06     16:00          1994.0        18.0       White
# 65530 2012-12-06     17:54          1987.0        25.0       White
# 65531 2012-12-06     22:22          1954.0        58.0       White
# 65532 2012-12-06     23:20          1985.0        27.0       Black
# 65534 2012-12-07      0:30          1985.0        27.0       White
#
#                         violation_raw  violation  search_conducted  \
# 0                            Speeding   Speeding             False
# ...

# %% [markdown]
# # What is the mean stop duration ?

# %%
df.head(1)
# Out:
#    stop_date stop_time        driver_gender  driver_age_raw  driver_age  \
# 0 2005-01-02      1:55  2005-01-02 00:00:00          1985.0        20.0
#
#   driver_race violation_raw violation  search_conducted stop_outcome  \
# 0       White      Speeding  Speeding             False     Citation
#
#   is_arrested stop_duration  drugs_related_stop
# 0       False      0-15 Min               False

# %%
df['stop_duration'].value_counts()
# Out:
# 0-15 Min     47080
# 16-30 Min    11331
# 30+ Min       2619
# 2                1
# Name: stop_duration, dtype: int64

# %%
df['stop_duration'].replace(['0-15 Min','16-30 Min','30+ Min'],['7.5','23','45'],inplace=True)

# %%
df['stop_duration'].value_counts()
# Out:
# 7.5     47080
# 23.0    11331
# 45.0     2619
# 2.0         1
# Name: stop_duration, dtype: int64

# %%
# Now Convert It's value to int type

# %%
df['stop_duration']=pd.to_numeric(df['stop_duration'])

# %%
df.dtypes
# Out:
# stop_date             datetime64[ns]
# stop_time                     object
# driver_gender                 object
# driver_age_raw               float64
# driver_age                   float64
# driver_race                   object
# violation_raw                 object
# violation                     object
# search_conducted                bool
# stop_outcome                  object
# is_arrested                   object
# stop_duration                float64
# drugs_related_stop              bool
# dtype: object
